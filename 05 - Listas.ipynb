# %% [markdown]
# ### **Minhas Listas**

# %%
minha_lista = []
print(type(minha_lista))
# Out:
# <class 'list'>

# %%
minha_lista = [10, 20, 30]
lista_nomes = ["Arley", "Jheniffer", "Davi", "Carolina", "Matheus"]
lista_mista = [1, 2, "Hello", [1, 2, 3]]
print(lista_mista)
# Out:
# [1, 2, 'Hello', [1, 2, 3]]

# %%
list_1 = [1, 2 ,3]
list_2 = [4, 5, 6]
list_3 = [7, 8 ,9]
list_4 = [list_1, list_2, list_3]
print(list_4)

print(list_4[0] [2])

print(list_4 [2] [1])
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# 3
# 8

# %%
list_ex = [1, 2, 3]
list_ex.append(4)
list_ex.append(4)
list_ex.pop()
list_ex.pop()
print(list_ex)
# Out:
# [1, 2, 3]

# %%
list_alpha = ["e","c","a","d","b"]
lista_ordenada = sorted(list_alpha)
list_alpha.sort()
list_alpha.reverse()



print(list_alpha)
print(lista_ordenada)
# Out:
# ['e', 'd', 'c', 'b', 'a']
# ['a', 'b', 'c', 'd', 'e']
