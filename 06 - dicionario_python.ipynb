# %% [markdown]
# ### *Dicionário Python* = "chave" : "valor", ....

# %%
from pprint import pprint
meu_dicionario = {"nome": "Arley", "sobrenome": "Batistela", "idade": 47, "peso": 80, "filhos": ["Mariazinha", "Pedrinho","Joãozinho"]}

#pprint(meu_dicionario)
meu_dicionario ["nome"] = "Kleber"
meu_dicionario ["Cidade"] = "Pindamonhangaba"

#print(meu_dicionario ["nome"], meu_dicionario["sobrenome"])
pprint(meu_dicionario)
# Out:
# {'Cidade': 'Pindamonhangaba',
#  'filhos': ['Mariazinha', 'Pedrinho', 'Joãozinho'],
#  'idade': 47,
#  'nome': 'Kleber',
#  'peso': 80,
#  'sobrenome': 'Batistela'}
